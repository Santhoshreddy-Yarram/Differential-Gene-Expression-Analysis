# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C:\\Users\\91918")

# %%
import pandas as pd
df=pd.read_excel("resLFC_Y_B6J_4w_AL_vs_NRDR.xlsx")

# %%
df
# Out:
#            Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue  \
# 0                Xkr4    1.375127       -0.020519  0.289752  0.683132
# 1              Gm7341    1.311742        0.056132  0.293330  0.396530
# 2               Sox17   31.231318        0.024077  0.205507  0.871209
# 3              Gm7357    5.921844        0.003447  0.267812  0.976182
# 4              Gm6085   50.962861        0.281661  0.220775  0.086261
# ...               ...         ...             ...       ...       ...
# 22873      AC125149.1    5.412648       -0.451383  0.649777  0.029091
# 22874      AC168977.2    2.975387       -0.017434  0.277389  0.848031
# 22875      AC168977.1    1.426839       -0.122484  0.324438  0.065331
# 22876      AC149090.1  584.916210       -0.219303  0.151814  0.093259
# 22877  CAAA01147332.1  469.139410        0.042226  0.141278  0.736688
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
#df.columns

# %%
#display(all_padj_values)

# %%
padj_filtered = df[df["padj"] < 0.05]
display(padj_filtered)
# Out:
#       Unnamed: 0      baseMean  log2FoldChange     lfcSE        pvalue  \
# 13        Rb1cc1   1574.084970        0.380661  0.114559  3.351949e-04
# 21        Gm9826  23888.126191        0.626043  0.114376  7.795358e-09
# 24       Gm16284      8.632604       -1.910256  0.684834  2.476734e-04
# 56         Tram1   4916.542042       -0.332693  0.131787  5.036685e-03
# 81          Jph1     55.481709        1.405542  0.301990  2.161342e-07
# ...          ...           ...             ...       ...           ...
# 22848  Rab11fip2    386.419585        0.853326  0.164901  2.500384e-08
# 22852     Nanos1      7.645563        2.437464  0.839880  1.622293e-04
# 22854    Dennd10    828.927228       -0.466743  0.188369  3.111841e-03
# 22857       Grk5    285.166580       -1.767624  0.199352  4.717929e-20
# 22860     Gm5521    328.246277       -0.656727  0.184080  5.143313e-05
#
#                padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
de_genes = df[df["padj"] < 0.05]  # storing the padj coulumn values information which are less then 0.05 in a varible called de_genes
display(de_genes)
# Out:
#       Unnamed: 0      baseMean  log2FoldChange     lfcSE        pvalue  \
# 13        Rb1cc1   1574.084970        0.380661  0.114559  3.351949e-04
# 21        Gm9826  23888.126191        0.626043  0.114376  7.795358e-09
# 24       Gm16284      8.632604       -1.910256  0.684834  2.476734e-04
# 56         Tram1   4916.542042       -0.332693  0.131787  5.036685e-03
# 81          Jph1     55.481709        1.405542  0.301990  2.161342e-07
# ...          ...           ...             ...       ...           ...
# 22848  Rab11fip2    386.419585        0.853326  0.164901  2.500384e-08
# 22852     Nanos1      7.645563        2.437464  0.839880  1.622293e-04
# 22854    Dennd10    828.927228       -0.466743  0.188369  3.111841e-03
# 22857       Grk5    285.166580       -1.767624  0.199352  4.717929e-20
# 22860     Gm5521    328.246277       -0.656727  0.184080  5.143313e-05
#
#                padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
gene_list = de_genes["gene"].tolist()

# %%
output_file = "de_Genes_Y_B6J_4w_AL_vs_NRDR.xlsx"
de_genes.to_excel(output_file, index=False, engine='openpyxl')

# %%
print(f"Total de genes (padj < 0.05): {len(gene_list)}")
# Out:
# Total de genes (padj < 0.05): 2482

# %%
# Filter for differentially expressed genes (padj ≤ 0.05)
df_filtered = df[df["padj"] <= 0.05]

# Extract gene names and their log2FoldChange values as a list
degs_list = df_filtered[["gene", "log2FoldChange"]].values.tolist()

# Save to Excel
df_filtered.to_excel("Filtered_DEGs.xlsx", index=False, engine="openpyxl")

# Display first few results
#display(df_filtered.head())
#display(f"Total DEGs (padj ≤ 0.05): {len(df_filtered)}")
