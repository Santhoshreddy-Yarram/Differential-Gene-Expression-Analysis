# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C://Users//91918")

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd 
from scipy.stats import binomtest

# %%
proteome = pd.read_excel("C:/Users/91918/overlaps_dep's_O_AL vs NRDR.xlsx")

# %%
from scipy.stats import binomtest

# Determine upregulated and downregulated genes
upregulated = proteome[proteome['AVG Log2 Ratio'] > 0]
downregulated = proteome[proteome['AVG Log2 Ratio'] < 0]

# Count values
num_up = len(upregulated)
num_down = len(downregulated)
total_genes = num_up + num_down

# Perform binomial test
num_co, num_anti = len(co_directional), len(anti_directional)
p_value = binomtest(num_up, num_up + num_down, p=0.5, alternative='greater').pvalue


# Print results
# .4e is the scientific notation value,for the better readability
print(f"upregulated: {num_up}, downregulated: {num_down}, P-value: {p_value:.4e}")
# Out:
# upregulated: 495, downregulated: 788, P-value: 1.0000e+00

# %%
transcriptome = pd.read_excel("C:/Users/91918/overlaps_deg's_Y_AL vs NRDR.xlsx")

# %%
from scipy.stats import binomtest

# Determine upregulated and downregulated genes
upregulated = transcriptome[transcriptome['log2FoldChange.1'] > 0]
downregulated = transcriptome[transcriptome['log2FoldChange.1'] < 0]

# Count values
num_up = len(upregulated)
num_down = len(downregulated)
total_genes = num_up + num_down

# Perform binomial test
num_co, num_anti = len(co_directional), len(anti_directional)
p_value = binomtest(num_up, num_up + num_down, p=0.5, alternative='greater').pvalue


# Print results
# .4e is the scientific notation value,for the better readability
print(f"upregulated: {num_up}, downregulated: {num_down}, P-value: {p_value:.4e}")
# Out:
# upregulated: 277, downregulated: 239, P-value: 5.1628e-02
