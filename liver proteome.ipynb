# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C:\\Users\\91918")

# %%
import pandas as pd
lp=pd.read_excel("liver proteome.xlsx")

# %%
lp

# %%
lp.shape
# Out:
# (85298, 20)

# %%
lp.columns
# Out:
# Index(['Comparison (group1/group2)', 'Group', 'ProteinGroups',
#        'AVG Log2 Ratio', 'Absolute AVG Log2 Ratio', 'Pvalue', 'Qvalue',
#        '# of Ratios', 'UniProtIds', 'Genes', 'ProteinDescriptions',
#        'ProteinNames', '# Unique Total Peptides', '% Change', 'Ratio',
#        'Condition Numerator', 'Condition Denominator', 'GO Cellular Component',
#        'GO Molecular Function', 'GO Biological Process'],
#       dtype='object')

# %%
lp.head(3)
# Out:
#   Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0              O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1              O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                O_NR / Y_DR  Q8C196        Q8C196       -0.710514
#
#    Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# 0                 0.809178   0.000000e+00   0.000000e+00         3847
# 1                 0.913840   0.000000e+00   0.000000e+00         3846
# 2                 0.710514  3.164386e-307  4.360523e-303         3842
#
#   UniProtIds Genes                                ProteinDescriptions  \
# 0     Q8C196  Cps1  Carbamoyl-phosphate synthase [ammonia], mitoch...
# 1     Q8C196  Cps1  Carbamoyl-phosphate synthase [ammonia], mitoch...
# 2     Q8C196  Cps1  Carbamoyl-phosphate synthase [ammonia], mitoch...
#
#   ProteinNames  # Unique Total Peptides   % Change     Ratio  \
# 0   CPSM_MOUSE                      151 -42.929303  0.570707
# ...

# %%
lp.tail(4)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio    Pvalue    Qvalue  # of Ratios UniProtIds  \
# 85294                 0.070849  0.999912  0.484628           43     Q9QUR7
# 85295                 0.067533  0.999976  0.484645           52     P54731
# 85296                 0.041905  0.999981  0.484645          213     Q99K48
# 85297                 0.032731  0.999962  0.484645           86     Q9Z0N1
#
#          Genes                                ProteinDescriptions  \
# 85294     Pin1  Peptidyl-prolyl cis-trans isomerase NIMA-inter...
# 85295     Faf1                            FAS-associated factor 1
# ...

# %%
lp.isna

# %%
print(lp["Genes"])
# Out:
# 0           Cps1
# 1           Cps1
# 2           Cps1
# 3           Cps1
# 4           Cps1
#           ...
# 85293       Tmx2
# 85294       Pin1
# 85295       Faf1
# 85296       Nono
# 85297    Eif2s3x
# Name: Genes, Length: 85298, dtype: object

# %%
unique_genes=lp["Genes"].unique()
print(unique_genes)
# Out:
# ['Cps1' 'Myh9' 'Fasn' ... 'Ccdc93' 'Mib1' 'Taok3']

# %%
filtered_lp = lp[lp["Comparison (group1/group2)"] == "O_AL / Y_NRDR"] 
print(filtered_lp)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 10                 O_AL / Y_NRDR  Q8VDD5        Q8VDD5        0.749668
# 11                 O_AL / Y_NRDR  P19096        P19096        0.493128
# 13                 O_AL / Y_NRDR  Q99K67        Q99K67       -1.294483
# 23                 O_AL / Y_NRDR  P24549        P24549       -0.968203
# ...                          ...     ...           ...             ...
# 84888              O_AL / Y_NRDR  Q99KY4        Q99KY4        0.282322
# 84977              O_AL / Y_NRDR  Q9ER35        Q9ER35        0.161770
# 85011              O_AL / Y_NRDR  Q9Z0U1        Q9Z0U1        0.436748
# 85148              O_AL / Y_NRDR  Q922B1        Q922B1        0.084755
# 85245              O_AL / Y_NRDR  Q6P1F6        Q6P1F6        0.006318
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
num_unique_genes=lp["Genes"].nunique() 
print(f"number of unique genes: {num_unique_genes}")
# Out:
# number of unique genes: 3004

# %%
genes_in_comparison = filtered_lp["Genes"].unique() 
print(genes_in_comparison)
# Out:
# ['Cps1' 'Myh9' 'Fasn' ... 'Tjp2' 'Macrod1' 'Ppp2r2a']

# %%
print(f"Number of unique genes: {len(genes_in_comparison)}")
# Out:
# Number of unique genes: 2995

# %%
print(filtered_lp.isna().sum())
# Out:
# Comparison (group1/group2)     0
# Group                          0
# ProteinGroups                  0
# AVG Log2 Ratio                 0
# Absolute AVG Log2 Ratio        0
# Pvalue                         0
# Qvalue                         0
# # of Ratios                    0
# UniProtIds                    21
# Genes                         49
# ProteinDescriptions            0
# ProteinNames                   0
# # Unique Total Peptides        0
# % Change                       0
# Ratio                          0
# Condition Numerator            0
# Condition Denominator          0
# GO Cellular Component         57
# GO Molecular Function         69
# GO Biological Process         82
# dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import os
os.chdir("C:\\Users\\91918")

# %%
import pandas as pd
lp1=pd.read_excel("liver proteome.xlsx")

# %%
lp1
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_lp1 = lp1[lp1["Comparison (group1/group2)"] == "O_NR / Y_NRDR"] 
print(filtered_lp1)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 15                 O_NR / Y_NRDR  Q8VDD5        Q8VDD5        0.724024
# 27                 O_NR / Y_NRDR  P19096        P19096        0.500641
# 33                 O_NR / Y_NRDR  Q99K67        Q99K67       -1.229249
# 39                 O_NR / Y_NRDR  P41216        P41216       -0.734297
# ...                          ...     ...           ...             ...
# 84774              O_NR / Y_NRDR  P97450        P97450       -0.241298
# 84805              O_NR / Y_NRDR  Q99K95        Q99K95       -0.005052
# 84807              O_NR / Y_NRDR  P26040        P26040       -0.093439
# 84963              O_NR / Y_NRDR  P70699        P70699       -0.304868
# 84991              O_NR / Y_NRDR  Q91V16        Q91V16        0.057653
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
num_unique_genes = lp1["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")
# Out:
# number of unique genes: 3004

# %%
genes_in_comparison = filtered_lp1["Genes"].unique() 
print(genes_in_comparison)
# Out:
# ['Cps1' 'Myh9' 'Fasn' ... 'Ezr' 'Gaa' 'Lyrm5']

# %%
print(f"Number of unique genes: {len(genes_in_comparison)}")
# Out:
# Number of unique genes: 2996

# %%
print(filtered_lp1.isna().sum())
# Out:
# Comparison (group1/group2)     0
# Group                          0
# ProteinGroups                  0
# AVG Log2 Ratio                 0
# Absolute AVG Log2 Ratio        0
# Pvalue                         0
# Qvalue                         0
# # of Ratios                    0
# UniProtIds                    21
# Genes                         49
# ProteinDescriptions            0
# ProteinNames                   0
# # Unique Total Peptides        0
# % Change                       0
# Ratio                          0
# Condition Numerator            0
# Condition Denominator          0
# GO Cellular Component         57
# GO Molecular Function         69
# GO Biological Process         82
# dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
lp2 = pd.read_excel("liver proteome.xlsx")

# %%
lp2
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_lp2= lp2[lp2["Comparison (group1/group2)"] == "O_NR / Y_DR"] 
print(filtered_lp2)

# %%
genes_in_comparison = filtered_lp2["Genes"]
print(genes_in_comparison)

# %%
print(f"Number of unique genes: {len(genes_in_comparison)}")

# %%
print(filtered_lp2.isna().sum())

# %%
pwd

# %%
lp3 = pd.read_excel("liver proteome.xlsx")

# %%
lp3

# %%
filtered_lp3 = lp3[lp3["Comparison (group1/group2)"] == "O_AL / Y_DR"]
print(filtered_lp3)

# %%
num_unique_genes=lp3["Genes"].nunique() 
print(f"number of unique genes: {num_unique_genes}")

# %%
genes_in_comparison = filtered_lp3["Genes"]
print(genes_in_comparison)

# %%
print(filtered_lp3.isna().sum())

# %%
pwd

# %%
lp4=pd.read_excel("liver proteome.xlsx")

# %%
lp4

# %%
filtered_lp4 =lp4[lp4["Comparison (group1/group2)"] == "O_NRDR / O_NR"]
print(filtered_lp4)

# %%
num_unique_genes = lp4["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")

# %%
genes_in_comparison = filtered_lp4["Genes"]
print(genes_in_comparison)

# %%
print(filtered_lp4.isna().sum())

# %%
pwd

# %%
lp5=pd.read_excel("liver proteome.xlsx")

# %%
lp5

# %%
filtered_lp5=lp5[lp5["Comparison (group1/group2)"]== "O_NRDR / O_AL"]
print(filtered_lp5)

# %%
num_unique_genes=lp5["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")

# %%
genes_in_comparison = filtered_lp5["Genes"]
print(genes_in_comparison)

# %%
print(filtered_lp5.isna().sum())

# %%
pwd

# %%
lp6=pd.read_excel("liver proteome.xlsx")

# %%
lp6

# %%
filtered_lp6=lp6[lp6["Comparison (group1/group2)"]== "O_NRDR / O_AL"]
print(filtered_lp6)

# %%
num_unique_genes=lp6["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")

# %%
genes_in_comparison = filtered_lp6["Genes"]
print(genes_in_comparison)

# %%
print(filtered_lp6.isna().sum())

# %%
pwd

# %%
import os 
os.chdir("C://Users//91918")

# %%
pwd

# %%
import pandas as pd
lp7=pd.read_excel("liver proteome.xlsx")

# %%
lp7

# %%
filtered_lp7=lp7[lp7["Comparison (group1/group2)"]== "O_DR / O_AL"]
print(filtered_lp7)

# %%
num_unique_genes=lp7["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")

# %%
genes_in_comparison = filtered_lp7["Genes"]
print(genes_in_comparison)

# %%
print(filtered_lp7.isna().sum())

# %%
pwd

# %%
lp7=pd.read_excel("liver proteome.xlsx")
