# %% [markdown]
# # loops

# %%
count=1
while count <5 :
    print("hello")
    count += 1
# Out:
# hello
# hello
# hello
# hello

# %%
print(count)
# Out:
# 5

# %%
#if you want to print a table
i=1
while i <= 10:
    print(i*3)
    i += 1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
n = int(input("enter number :   "))
i=1
while i <= 10:
    print(17*i)
    i += 1
# Out:
# enter number :    17
# 17
# 34
# 51
# 68
# 85
# 102
# 119
# 136
# 153
# 170
