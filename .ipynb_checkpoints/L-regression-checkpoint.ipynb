# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import os
os.chdir("C://Users//91918")

# %%
pwd
# Out:
# 'c:\\Users\\91918\\rna seq'

# %%
import pandas as pd                        # Reading and handling tabular data (Excel file).
import matplotlib.pyplot as plt            # Creating plots
import seaborn as sns                      # Enhancing visualization (scatter plots).
import numpy as np                         # Performing numerical operations (e.g., creating x-values).
from scipy.stats import linregress         # Performing linear regression analysis (calculating slope, intercept, and R²)

# Load overlapping genes from Step 
overlap = pd.read_excel("C:/Users/91918/Directional_Genes_O_AL vs DR.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd                        # Reading and handling tabular data (Excel file).
#       2 import matplotlib.pyplot as plt            # Creating plots
#       3 import seaborn as sns                      # Enhancing visualization (scatter plots).
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Extract log fold-change values
x = overlap['log2FoldChange.1']        # Transcriptome (DEGs) # x: Transcriptome log2 Fold Change (DEGs) → How much gene expression changes in RNA-seq.
y = overlap['AVG Log2 Ratio']

# %%
# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# %%
x_vals = np.linspace(min(x), max(x), 100)  
y_vals = slope * x_vals + intercept

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, color='blue', label="Overlapping Genes")
plt.plot(x_vals, y_vals, color='red', linestyle='dashed', label=f"Regression Line (R²={r_value**2:.2f})")

# Labels and title
plt.xlabel("Transcriptome log2FoldChange (DEGs)")
plt.ylabel("Proteome AVG Log2 Ratio (DEPs)")
plt.title("Directionality of DEGs vs. DEPs")
plt.legend()                                         # displays the legend box (for the blue dots and red line).
plt.grid(True)                                       #  Adds a grid to improve readability.


# Save plot
#plt.savefig("C:/Users/91918/Directionality_Plot_Y_AL vs NRDR.png", dpi=300)

# Show plot
plt.show()

# %%
print(f"Linear Regression Equation: y = {slope:.4f}x + {intercept:.4f}")
print(f"R-squared: {r_value**2:.4f}")
print(f"P-value: {p_value:.4e}")
# Out:
# Linear Regression Equation: y = -0.0994x + -0.0345
# R-squared: 0.0004
# P-value: 2.8196e-01

# %%
name="santhosh"
print(name)
# Out:
# santhosh
