# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C:\\Users\\91918")  # Double backslashes needed

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
df5 = pd.read_excel("resLFC_O_B6J_4w_AL_vs_NRDR.xlsx")

# %%
df5
# Out:
#            Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue  \
# 0                Xkr4    2.449316       -0.092137  0.281697  0.143563
# 1               Sox17   24.891324        0.022709  0.221704  0.856419
# 2              Gm7357    5.078738       -0.149079  0.299417  0.156674
# 3              Gm6085   42.499403        0.161571  0.206153  0.263125
# 4              Gm6119    5.569959        0.016735  0.247745  0.855255
# ...               ...         ...             ...       ...       ...
# 23623      AC125149.4    0.582299       -0.006389  0.265029  0.795766
# 23624      AC168977.2   11.055031       -0.109050  0.261238  0.333708
# 23625      AC168977.1   22.016405       -0.061860  0.257023  0.492945
# 23626      AC149090.1  610.601180       -0.254621  0.186760  0.077155
# 23627  CAAA01147332.1  408.820909       -0.154021  0.166995  0.245282
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
unique_genes = df5["gene"].unique()
print(unique_genes)
# Out:
# ['Xkr4' 'Sox17' 'Gm7357' ... 'AC168977.1' 'AC149090.1' 'CAAA01147332.1']

# %%
num_unique_genes = df5["gene"].nunique()
print(f"Number of unique genes: {num_unique_genes}")
# Out:
# Number of unique genes: 23628
