# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir(r"C:\Users\91918")  # Set working directory
print(os.listdir())  # Check available files
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.VirtualBox', '.virtual_documents', '.vscode', 'anaconda3', 'AppData', 'Application Data', 'Barplot_santhosh.png', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'Human_genome.xlxs.xlsx', 'IntelGraphicsProfiles', 'iris_dataset.txt', 'Jedi', 'Links', 'Local Settings', 'Microsoft', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{64783d22-e0ca-11ef-8b5f-cb0936dff8bb}.TM.blf', 'NTUSER.DAT{64783d22-e0ca-11ef-8b5f-cb0936dff8bb}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{64783d22-e0ca-11ef-8b5f-cb0936dff8bb}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'PROGRAMMING', 'R class 1.R', 'R.class- -5.R', 'R.script1.R', 'R.scripts2.R', 'R.scripts3.R', 'Recent', 'resLFC_O_B6J_4w_AL_vs_DR.xlsx', 'resLFC_O_B6J_4w_AL_vs_NR.xlsx', 'res
# ...

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
df1 = pd.read_excel("resLFC_Y_B6J_4w_AL_vs_DR.xlsx")

# %%
df1
# Out:
#           Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue  \
# 0               Zzz3   924.612989        0.207958  0.126069  0.066322
# 1              Zzef1  1202.105048        0.085021  0.223921  0.560661
# 2                Zyx   847.096494        0.362974  0.328963  0.056781
# 3             Zyg11b  2336.250924        0.102107  0.129472  0.378199
# 4             Zyg11a    58.329681        0.032908  0.212517  0.819979
# ...              ...          ...             ...       ...       ...
# 22873  0610010F05Rik   724.076105       -0.078786  0.131940  0.498742
# 22874  0610009L18Rik    12.334087       -0.229916  0.324790  0.139484
# 22875  0610009E02Rik     3.800484       -0.002768  0.263786  0.976496
# 22876  0610009B22Rik   685.437928       -0.843077  0.255959  0.000089
# 22877  0610005C13Rik  3887.039850        0.378518  0.126990  0.001266
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of           Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue  \
# 0               Zzz3   924.612989        0.207958  0.126069  0.066322
# 1              Zzef1  1202.105048        0.085021  0.223921  0.560661
# 2                Zyx   847.096494        0.362974  0.328963  0.056781
# 3             Zyg11b  2336.250924        0.102107  0.129472  0.378199
# 4             Zyg11a    58.329681        0.032908  0.212517  0.819979
# ...              ...          ...             ...       ...       ...
# 22873  0610010F05Rik   724.076105       -0.078786  0.131940  0.498742
# 22874  0610009L18Rik    12.334087       -0.229916  0.324790  0.139484
# 22875  0610009E02Rik     3.800484       -0.002768  0.263786  0.976496
# 22876  0610009B22Rik   685.437928       -0.843077  0.255959  0.000089
# 22877  0610005C13Rik  3887.039850        0.378518  0.126990  0.001266
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
df.head(2)
# Out:
#   Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue      padj  \
# 0       Zzz3   924.612989        0.207958  0.126069  0.066322  0.242158
# 1      Zzef1  1202.105048        0.085021  0.223921  0.560661  0.781190
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9   gene  log2FoldChange.1
# 0         NaN         NaN         NaN         NaN   Zzz3          0.207958
# 1         NaN         NaN         NaN         NaN  Zzef1          0.085021

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'baseMean', 'log2FoldChange', 'lfcSE', 'pvalue', 'padj',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'gene',
#        'log2FoldChange.1'],
#       dtype='object')

# %%
df.tail
# Out:
# <bound method NDFrame.tail of           Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue  \
# 0               Zzz3   924.612989        0.207958  0.126069  0.066322
# 1              Zzef1  1202.105048        0.085021  0.223921  0.560661
# 2                Zyx   847.096494        0.362974  0.328963  0.056781
# 3             Zyg11b  2336.250924        0.102107  0.129472  0.378199
# 4             Zyg11a    58.329681        0.032908  0.212517  0.819979
# ...              ...          ...             ...       ...       ...
# 22873  0610010F05Rik   724.076105       -0.078786  0.131940  0.498742
# 22874  0610009L18Rik    12.334087       -0.229916  0.324790  0.139484
# 22875  0610009E02Rik     3.800484       -0.002768  0.263786  0.976496
# 22876  0610009B22Rik   685.437928       -0.843077  0.255959  0.000089
# 22877  0610005C13Rik  3887.039850        0.378518  0.126990  0.001266
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
print(df["gene"].tail())
# Out:
# 22873    0610010F05Rik
# 22874    0610009L18Rik
# 22875    0610009E02Rik
# 22876    0610009B22Rik
# 22877    0610005C13Rik
# Name: gene, dtype: object

# %%
df.shape
# Out:
# (22878, 12)

# %%
df.isna
# Out:
# <bound method DataFrame.isna of           Unnamed: 0     baseMean  log2FoldChange     lfcSE    pvalue  \
# 0               Zzz3   924.612989        0.207958  0.126069  0.066322
# 1              Zzef1  1202.105048        0.085021  0.223921  0.560661
# 2                Zyx   847.096494        0.362974  0.328963  0.056781
# 3             Zyg11b  2336.250924        0.102107  0.129472  0.378199
# 4             Zyg11a    58.329681        0.032908  0.212517  0.819979
# ...              ...          ...             ...       ...       ...
# 22873  0610010F05Rik   724.076105       -0.078786  0.131940  0.498742
# 22874  0610009L18Rik    12.334087       -0.229916  0.324790  0.139484
# 22875  0610009E02Rik     3.800484       -0.002768  0.263786  0.976496
# 22876  0610009B22Rik   685.437928       -0.843077  0.255959  0.000089
# 22877  0610005C13Rik  3887.039850        0.378518  0.126990  0.001266
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
unique_genes=df["gene"].unique()
print(unique_genes)
# Out:
# ['Zzz3' 'Zzef1' 'Zyx' ... '0610009E02Rik' '0610009B22Rik' '0610005C13Rik']

# %%
num_unique_genes=df["gene"].nunique()
print(f" number of unique genes: {num_unique_genes}")
# Out:
#  number of unique genes: 22878
