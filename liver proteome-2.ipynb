# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C:/Users/91918")

# %%
import pandas as pd
df=pd.read_excel("liver proteome.xlsx")

# %%
df
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df = df[df["Comparison (group1/group2)"] == "O_DR / O_AL"]
print(filtered_df)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 9                    O_DR / O_AL  Q8C196        Q8C196        0.452917
# 18                   O_DR / O_AL  P19096        P19096       -0.383790
# 25                   O_DR / O_AL  Q91Y97        Q91Y97        0.644823
# 29                   O_DR / O_AL  Q99K67        Q99K67        0.948140
# 47                   O_DR / O_AL  Q91V92        Q91V92       -0.712077
# ...                          ...     ...           ...             ...
# 85201                O_DR / O_AL  Q8BHD7        Q8BHD7       -0.126343
# 85214                O_DR / O_AL  O88543        O88543       -0.238335
# 85220                O_DR / O_AL  Q9CQB2        Q9CQB2        0.243283
# 85274                O_DR / O_AL  Q9WTI7        Q9WTI7        0.088705
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
num_unique_genes = len(unique_genes)
print(f"Total number of unique genes: {num_unique_genes}")
# Out:
# Total number of unique genes: 2999

# %%
import numpy as np

has_nan = np.any(pd.isna(unique_genes)) 

if has_nan:
    print("There are NaN values in the unique genes.")
else:
    print("No NaN values in the unique genes.")
# Out:
# There are NaN values in the unique genes.

# %%
num_nan = np.sum(pd.isna(unique_genes))  # Count NaN values
print(f"Number of NaN values in unique genes: {num_nan}")
# Out:
# Number of NaN values in unique genes: 1

# %%
num_na_genes = na_genes.shape[0]
print(f"Number of NaN values in 'Genes': {num_na_genes}")
# Out:
# Number of NaN values in 'Genes': 51

# %%
num_actual_unique_genes = len(unique_genes)
print(f"Total actual unique genes (without NaN): {num_actual_unique_genes}")
# Out:
# Total actual unique genes (without NaN): 2999

# %%
num_genes = filtered_df["Genes"].notna().sum()
print(f"Total number of genes in 'O_DR / O_AL' comparison: {num_genes}")
# Out:
# Total number of genes in 'O_DR / O_AL' comparison: 2999

# %%
genes_in_comparison = filtered_df["Genes"]
print(genes_in_comparison)
# Out:
# 9           Cps1
# 18          Fasn
# 25         Aldob
# 29          Aass
# 47          Acly
#           ...
# 85201      Ptbp3
# 85214      Cops3
# 85220    Fam195a
# 85274      Myo1c
# 85297    Eif2s3x
# Name: Genes, Length: 3050, dtype: object

# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C://Users//91918")

# %%
import pandas as pd
df1=pd.read_excel("liver proteome.xlsx")

# %%
df1
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df1= df1[df1["Comparison (group1/group2)"] == "O_NR / O_AL"]
print(filtered_df1)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 3678                 O_NR / O_AL  Q99PL5        Q99PL5       -0.123758
# 3833                 O_NR / O_AL  P97501        P97501       -0.373383
# 3919                 O_NR / O_AL  P43883        P43883        0.524577
# 4995                 O_NR / O_AL  P25688        P25688       -0.308591
# 5092                 O_NR / O_AL  Q8CC88        Q8CC88        0.152147
# ...                          ...     ...           ...             ...
# 85130                O_NR / O_AL  Q8C0D5        Q8C0D5       -0.093973
# 85135                O_NR / O_AL  O08573        O08573       -0.080574
# 85140                O_NR / O_AL  Q61112        Q61112        0.041969
# 85183                O_NR / O_AL  Q6P542        Q6P542        0.231689
# 85216                O_NR / O_AL  Q8R1Q9        Q8R1Q9        0.073797
#
#        Absolute AVG Log2 Ratio        Pvalue        Qvalue  # of Ratios  \
# ...

# %%
num_unique_genes=df1["Genes"].nunique()
print(f"number of unique genes: {num_unique_genes}")
# Out:
# number of unique genes: 3004

# %%
unique_genes=3004
display(unique_genes)
# Out:
# 3004

# %%
unique_genes_list = list(unique_genes)

for gene in unique_genes_list:
    print(gene)
# Out:
# Cps1
# Myh9
# Fasn
# Aass
# Fth1
# Aldh1a1
# Sardh
# Aldob
# Pc
# Ehhadh
# Acsl1
# Cyp3a41a
# Ephx1
# Acly
# Rgn
# Cyp2e1
# Acadvl
# A1bg
# Pklr
# Cyp2f2
# Inmt
# Cyp4a14
# Cyp4a10
# Fn1
# A2m
# Pygl
# Oat
# Tgm1
# Dmgdh
# Apoa1
# Aifm1
# Cpt2
# Mug1
# Got2
# Cyp17a1
# Aco2
# Fmo3
# Papss2
# Rrbp1
# Mdh2
# Acaa2
# Hspg2
# Itih4
# Acadm
# Fmo1
# Gls2
# Fabp1
# Uqcrc2
# Vim
# Atp5a1
# Etfb
# Cp
# Hibadh
# Lasp1
# Vwa8
# Pdia4
# Pgd
# Hmgcs2
# Serpinb1a
# Cpt1a
# Tf
# Aldh7a1
# Gstm2
# Cyp1a2
# Hsd17b2
# Por
# Slc25a13
# Lmna
# Gstm1
# Ighm
# Hadha
# Bag3
# Ogdh
# Hsdl2
# Ak2
# Acat1
# Fmo5
# Alb
# Pdia3
# Agxt2
# Actn4
# Acadl
# Ugdh
# Aldh1l1
# Acox2
# Hadhb
# Gldc
# Fga
# Rpl7
# Aco1
# Hpd
# Me1
# Plin2
# Akr1c6
# Sord
# Tln1
# Sdha
# Tkt
# Atp5c1
# Cpox
# Ephx2
# Ethe1
# Decr1
# Acsm5
# Cyp2c40
# Fgb
# Acox1
# Arg1
# Plec
# Cyc1
# Hspa5
# Ass1
# Bhmt
# Ces1
# Ccbl2
# Cyp27a1
# Upb1
# Echs1
# nan
# Cyp3a11
# Hal
# Ca3
# Hadh
# Acacb
# Acaca
# Agxt
# Etfa
# Acsl5
# Ces1d
# Cth
# Gpx1
# ...

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
df2=pd.read_excel("liver proteome.xlsx")

# %%
df2
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df2= df2[df2["Comparison (group1/group2)"] == "Y_NRDR / Y_AL"]
print(filtered_df2)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 8                  Y_NRDR / Y_AL  Q8C196        Q8C196        0.441013
# 99                 Y_NRDR / Y_AL  Q99LB7        Q99LB7        0.236349
# 113                Y_NRDR / Y_AL  O88833        O88833        1.593028
# 123                Y_NRDR / Y_AL  Q99K67        Q99K67        0.921387
# 157                Y_NRDR / Y_AL  P52825        P52825        0.587015
# ...                          ...     ...           ...             ...
# 85264              Y_NRDR / Y_AL  P10711        P10711       -0.085954
# 85272              Y_NRDR / Y_AL  Q62087        Q62087        0.009904
# 85276              Y_NRDR / Y_AL  Q8BG05        Q8BG05       -0.062646
# 85284              Y_NRDR / Y_AL  Q9ESD7        Q9ESD7        0.009113
# 85291              Y_NRDR / Y_AL  P27786        P27786        0.043313
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
num_genes = filtered_df2["Genes"].count()
print(f"Total number of genes in 'Y_NRDR / Y_AL': {num_genes}")
# Out:
# Total number of genes in 'Y_NRDR / Y_AL': 2991

# %%
num_unique_genes = filtered_df2["Genes"].nunique()
print(f"Total number of unique genes: {num_unique_genes}")
# Out:
# Total number of unique genes: 2991

# %%
num_na_genes = filtered_df2["Genes"].isna().sum()
print(f"Number of NaN values in 'Genes': {num_na_genes}")
# Out:
# Number of NaN values in 'Genes': 49

# %%
num_na_genes = pd.isna(unique_genes).sum()
print(f"Number of NaN values in unique genes: {num_na_genes}")
# Out:
# Number of NaN values in unique genes: 0
