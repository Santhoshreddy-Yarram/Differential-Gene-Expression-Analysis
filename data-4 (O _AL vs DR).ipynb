# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import os
os.chdir("C:/Users/91918")  # Set working directory

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
df3 = pd.read_excel("resLFC_O_B6J_4w_AL_vs_DR.xlsx")

# %%
df3
# Out:
#            Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue  \
# 0                Xkr4    2.449316       -0.071344  0.250191  0.170297
# 1               Sox17   24.891324        0.051491  0.209792  0.644705
# 2              Gm7357    5.078738       -0.042688  0.229267  0.604081
# 3              Gm6085   42.499403        0.206451  0.213942  0.141489
# 4              Gm6119    5.569959        0.068553  0.237593  0.407243
# ...               ...         ...             ...       ...       ...
# 23623      AC125149.4    0.582299       -0.002597  0.239827  0.872425
# 23624      AC168977.2   11.055031       -0.110674  0.246800  0.264695
# 23625      AC168977.1   22.016405        0.027339  0.228497  0.722812
# 23626      AC149090.1  610.601180       -0.058899  0.156137  0.621408
# 23627  CAAA01147332.1  408.820909        0.038000  0.150419  0.748578
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
unique_genes=df3["gene"].unique()
print(unique_genes)
# Out:
# ['Xkr4' 'Sox17' 'Gm7357' ... 'AC168977.1' 'AC149090.1' 'CAAA01147332.1']

# %%
num_unique_genes=df3["gene"].nunique()
print(f"number of unique genes: {num_unique_genes}")
# Out:
# number of unique genes: 23628

# %%
df3.items
# Out:
# <bound method DataFrame.items of            Unnamed: 0    baseMean  log2FoldChange     lfcSE    pvalue  \
# 0                Xkr4    2.449316       -0.071344  0.250191  0.170297
# 1               Sox17   24.891324        0.051491  0.209792  0.644705
# 2              Gm7357    5.078738       -0.042688  0.229267  0.604081
# 3              Gm6085   42.499403        0.206451  0.213942  0.141489
# 4              Gm6119    5.569959        0.068553  0.237593  0.407243
# ...               ...         ...             ...       ...       ...
# 23623      AC125149.4    0.582299       -0.002597  0.239827  0.872425
# 23624      AC168977.2   11.055031       -0.110674  0.246800  0.264695
# 23625      AC168977.1   22.016405        0.027339  0.228497  0.722812
# 23626      AC149090.1  610.601180       -0.058899  0.156137  0.621408
# 23627  CAAA01147332.1  408.820909        0.038000  0.150419  0.748578
#
#            padj  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...
