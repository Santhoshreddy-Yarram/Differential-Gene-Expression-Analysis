# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os
os.chdir("C://Users//91918")

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
df=pd.read_excel("liver proteome.xlsx")

# %%
df
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
df.columns
# Out:
# Index(['Comparison (group1/group2)', 'Group', 'ProteinGroups',
#        'AVG Log2 Ratio', 'Absolute AVG Log2 Ratio', 'Pvalue', 'Qvalue',
#        '# of Ratios', 'UniProtIds', 'Genes', 'ProteinDescriptions',
#        'ProteinNames', '# Unique Total Peptides', '% Change', 'Ratio',
#        'Condition Numerator', 'Condition Denominator', 'GO Cellular Component',
#        'GO Molecular Function', 'GO Biological Process'],
#       dtype='object')

# %%
#display(df["Qvalue"])

# %%
find_Qvalue_df=df[df["Qvalue"] < 0.05]
#display(find_Qvalue_df)

# %%
Qvalue_filtered = df[df["Qvalue"] < 0.05]
#display(Qvalue_filtered)

# %%
filtered_df= df[df["Comparison (group1/group2)"] == "O_DR / O_AL"]
display(filtered_df)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 9                    O_DR / O_AL  Q8C196        Q8C196        0.452917
# 18                   O_DR / O_AL  P19096        P19096       -0.383790
# 25                   O_DR / O_AL  Q91Y97        Q91Y97        0.644823
# 29                   O_DR / O_AL  Q99K67        Q99K67        0.948140
# 47                   O_DR / O_AL  Q91V92        Q91V92       -0.712077
# ...                          ...     ...           ...             ...
# 85201                O_DR / O_AL  Q8BHD7        Q8BHD7       -0.126343
# 85214                O_DR / O_AL  O88543        O88543       -0.238335
# 85220                O_DR / O_AL  Q9CQB2        Q9CQB2        0.243283
# 85274                O_DR / O_AL  Q9WTI7        Q9WTI7        0.088705
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
#display(filtered_df["Qvalue"])

# %%
qvalue_filtered = filtered_df[filtered_df["Qvalue"] < 0.05]
display(qvalue_filtered)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 9                    O_DR / O_AL  Q8C196        Q8C196        0.452917
# 18                   O_DR / O_AL  P19096        P19096       -0.383790
# 25                   O_DR / O_AL  Q91Y97        Q91Y97        0.644823
# 29                   O_DR / O_AL  Q99K67        Q99K67        0.948140
# 47                   O_DR / O_AL  Q91V92        Q91V92       -0.712077
# ...                          ...     ...           ...             ...
# 31647                O_DR / O_AL  B1AR13        B1AR13        0.328305
# 31654                O_DR / O_AL  Q922E4        Q922E4       -0.111135
# 31729                O_DR / O_AL  Q61035        Q61035       -0.223675
# 31753                O_DR / O_AL  P62918        P62918       -0.112780
# 31831                O_DR / O_AL  P46425        P46425        0.596243
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
qvalue_filtered = filtered_df[filtered_df["Qvalue"] < 0.05]
num_qvalues = len(qvalue_filtered)
print(f"Number of Qvalue entries < 0.05: {num_qvalues}")
# Out:
# Number of Qvalue entries < 0.05: 1343

# %%
display(qvalue_filtered)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 9                    O_DR / O_AL  Q8C196        Q8C196        0.452917
# 18                   O_DR / O_AL  P19096        P19096       -0.383790
# 25                   O_DR / O_AL  Q91Y97        Q91Y97        0.644823
# 29                   O_DR / O_AL  Q99K67        Q99K67        0.948140
# 47                   O_DR / O_AL  Q91V92        Q91V92       -0.712077
# ...                          ...     ...           ...             ...
# 31647                O_DR / O_AL  B1AR13        B1AR13        0.328305
# 31654                O_DR / O_AL  Q922E4        Q922E4       -0.111135
# 31729                O_DR / O_AL  Q61035        Q61035       -0.223675
# 31753                O_DR / O_AL  P62918        P62918       -0.112780
# 31831                O_DR / O_AL  P46425        P46425        0.596243
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
#number of genes which are differentially expressed (<0.05) in O_DR / O_AL are =1343

# %%
# Extract only gene names
differentially_expressed_genes = filtered_df["Genes"].tolist()

# Display first 10 genes
print(differentially_expressed_genes[:10])
# Out:
# ['Cps1', 'Fasn', 'Aldob', 'Aass', 'Acly', 'Pc', 'Myh9', 'Sardh', 'Tf', 'Aco2']

# %%
filtered_df[["Genes",]].to_csv("O_DR_O_AL_DEGs.csv", index=False)

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import os 
os.chdir("C://Users//91918")

# %%
import pandas as pd
df1=pd.read_excel("liver proteome.xlsx")

# %%
df1
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df1=df1[df1["Comparison (group1/group2)"] == "O_NR / O_AL"]
display(filtered_df1) # display will give a clear table of the observing data
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 3678                 O_NR / O_AL  Q99PL5        Q99PL5       -0.123758
# 3833                 O_NR / O_AL  P97501        P97501       -0.373383
# 3919                 O_NR / O_AL  P43883        P43883        0.524577
# 4995                 O_NR / O_AL  P25688        P25688       -0.308591
# 5092                 O_NR / O_AL  Q8CC88        Q8CC88        0.152147
# ...                          ...     ...           ...             ...
# 85130                O_NR / O_AL  Q8C0D5        Q8C0D5       -0.093973
# 85135                O_NR / O_AL  O08573        O08573       -0.080574
# 85140                O_NR / O_AL  Q61112        Q61112        0.041969
# 85183                O_NR / O_AL  Q6P542        Q6P542        0.231689
# 85216                O_NR / O_AL  Q8R1Q9        Q8R1Q9        0.073797
#
#        Absolute AVG Log2 Ratio        Pvalue        Qvalue  # of Ratios  \
# ...

# %%
display(filtered_df1["Qvalue"])
# Out:
# 3678     3.859546e-12
# 3833     8.113779e-12
# 3919     1.231219e-11
# 4995     1.068494e-09
# 5092     1.495820e-09
#              ...
# 85130    4.835146e-01
# 85135    4.835625e-01
# 85140    4.835664e-01
# 85183    4.838266e-01
# 85216    4.840683e-01
# Name: Qvalue, Length: 3052, dtype: float64

# %%
display(filtered_df1["Qvalue"] < 0.05)
# Out:
# 3678      True
# 3833      True
# 3919      True
# 4995      True
# 5092      True
#          ...
# 85130    False
# 85135    False
# 85140    False
# 85183    False
# 85216    False
# Name: Qvalue, Length: 3052, dtype: bool

# %%
filtered_qvalue=filtered_df1[filtered_df1["Qvalue"] < 0.05]
display(filtered_qvalue)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 3678                 O_NR / O_AL  Q99PL5        Q99PL5       -0.123758
# 3833                 O_NR / O_AL  P97501        P97501       -0.373383
# 3919                 O_NR / O_AL  P43883        P43883        0.524577
# 4995                 O_NR / O_AL  P25688        P25688       -0.308591
# 5092                 O_NR / O_AL  Q8CC88        Q8CC88        0.152147
# ...                          ...     ...           ...             ...
# 31799                O_NR / O_AL  Q99J56        Q99J56        0.012121
# 31811                O_NR / O_AL  Q9CWL8        Q9CWL8        0.310333
# 31816                O_NR / O_AL  Q9CQZ0        Q9CQZ0        0.248691
# 31830                O_NR / O_AL  P50171        P50171       -0.018059
# 31869                O_NR / O_AL  P70362        P70362        0.166774
#
#        Absolute AVG Log2 Ratio        Pvalue        Qvalue  # of Ratios  \
# ...

# %%
qvalue_filtered = filtered_df1[filtered_df1["Qvalue"] < 0.05]
num_qvalues = len(qvalue_filtered)
print(f"Number of Qvalue entries < 0.05: {num_qvalues}")
# Out:
# Number of Qvalue entries < 0.05: 424

# %%
# differentially expressed genes in (O_AL / O_NR) are = 424

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
df2=df1

# %%
df2
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df2=df2[df2["Comparison (group1/group2)"] == "O_NRDR / O_AL"]
display(filtered_df2)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 5                  O_NRDR / O_AL  Q8C196        Q8C196        0.510709
# 12                 O_NRDR / O_AL  P19096        P19096       -0.392575
# 30                 O_NRDR / O_AL  Q99K67        Q99K67        0.903527
# 38                 O_NRDR / O_AL  Q9DBM2        Q9DBM2        0.523532
# 40                 O_NRDR / O_AL  Q99LB7        Q99LB7        0.383591
# ...                          ...     ...           ...             ...
# 85084              O_NRDR / O_AL  P61965        P61965       -0.017083
# 85150              O_NRDR / O_AL  Q921F2        Q921F2       -0.104056
# 85238              O_NRDR / O_AL  P56528        P56528       -0.058562
# 85258              O_NRDR / O_AL  Q99L27        Q99L27       -0.461384
# 85288              O_NRDR / O_AL  Q9R0A0        Q9R0A0        0.195764
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
display(filtered_df2["Qvalue"])
# Out:
# 5        9.914122e-257
# 12       6.492391e-151
# 30       5.025566e-100
# 38        1.831249e-92
# 40        5.294740e-92
#              ...
# 85084     4.831542e-01
# 85150     4.835841e-01
# 85238     4.842191e-01
# 85258     4.843862e-01
# 85288     4.846000e-01
# Name: Qvalue, Length: 3049, dtype: float64

# %%
filtered_qvalue=filtered_df2[filtered_df2["Qvalue"] < 0.05]
display(filtered_qvalue)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 5                  O_NRDR / O_AL  Q8C196        Q8C196        0.510709
# 12                 O_NRDR / O_AL  P19096        P19096       -0.392575
# 30                 O_NRDR / O_AL  Q99K67        Q99K67        0.903527
# 38                 O_NRDR / O_AL  Q9DBM2        Q9DBM2        0.523532
# 40                 O_NRDR / O_AL  Q99LB7        Q99LB7        0.383591
# ...                          ...     ...           ...             ...
# 31646              O_NRDR / O_AL  O55042        O55042        0.232723
# 31660              O_NRDR / O_AL  Q60605        Q60605       -0.326463
# 31721              O_NRDR / O_AL  P63276        P63276       -0.093146
# 31804              O_NRDR / O_AL  Q569Z6        Q569Z6       -0.304713
# 31852              O_NRDR / O_AL  O88487        O88487       -0.066315
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
num_qvalues=len(filtered_qvalue)
print(f"number of qvalues < 0.05: {num_qvalues}")
# Out:
# number of qvalues < 0.05: 1367

# %%
# differrentially expressed genes in O_AL / O_NRDR are =1367

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
df3=df2

# %%
df3
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df3=df3[df3["Comparison (group1/group2)"] == "Y_DR / Y_AL"]
display(filtered_df3)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 41                   Y_DR / Y_AL  Q8C196        Q8C196        0.237687
# 229                  Y_DR / Y_AL  Q99LB7        Q99LB7        0.271470
# 328                  Y_DR / Y_AL  Q99K67        Q99K67        0.625419
# 429                  Y_DR / Y_AL  P40936        P40936       -0.526075
# 478                  Y_DR / Y_AL  Q571F8        Q571F8        0.503011
# ...                          ...     ...           ...             ...
# 85154                Y_DR / Y_AL  P15532        P15532       -0.392744
# 85229                Y_DR / Y_AL  Q80UP8        Q80UP8       -0.318158
# 85256                Y_DR / Y_AL  Q9CQF3        Q9CQF3        0.416619
# 85280                Y_DR / Y_AL  O88738        O88738       -0.281120
# 85289                Y_DR / Y_AL  P32883        P32883        0.000107
#
#        Absolute AVG Log2 Ratio        Pvalue        Qvalue  # of Ratios  \
# ...

# %%
display(filtered_df3["Qvalue"])
# Out:
# 41       5.569031e-92
# 229      9.607472e-50
# 328      1.095063e-44
# 429      4.373689e-40
# 478      2.927314e-38
#              ...
# 85154    4.836071e-01
# 85229    4.841624e-01
# 85256    4.843636e-01
# 85280    4.845820e-01
# 85289    4.846151e-01
# Name: Qvalue, Length: 3046, dtype: float64

# %%
filtered_qvalue=filtered_df3[filtered_df3["Qvalue"] < 0.05]
num_qvalue=len(filtered_qvalue)
print(f"number of qvalues <0.05: {num_qvalue}")
# Out:
# number of qvalues <0.05: 1066

# %%
# diffrentially expressed genes in (Y_AL / Y_DR) are =1066

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
df4=df3

# %%
df4
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df4=df4[df4["Comparison (group1/group2)"] == "Y_NR / Y_AL"]
display(filtered_df4)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 4325                 Y_NR / Y_AL  P04264        P04264        0.854003
# 4913                 Y_NR / Y_AL  Q05920        Q05920        0.001992
# 6127                 Y_NR / Y_AL  P35527        P35527        0.549248
# 6383                 Y_NR / Y_AL  P35908        P35908        0.590602
# 7835                 Y_NR / Y_AL  Q9R0H0        Q9R0H0       -0.336049
# ...                          ...     ...           ...             ...
# 85266                Y_NR / Y_AL  Q76LS9        Q76LS9       -0.282291
# 85281                Y_NR / Y_AL  O88829        O88829        0.111293
# 85283                Y_NR / Y_AL  Q3TIV5        Q3TIV5        0.043075
# 85287                Y_NR / Y_AL  Q9WUP7        Q9WUP7        0.076906
# 85290                Y_NR / Y_AL  P16294        P16294       -0.095468
#
#        Absolute AVG Log2 Ratio        Pvalue        Qvalue  # of Ratios  \
# ...

# %%
display(filtered_df4["Qvalue"])
# Out:
# 4325     7.632704e-11
# 4913     8.180000e-10
# 6127     3.555242e-08
# 6383     6.983229e-08
# 7835     1.164328e-06
#              ...
# 85266    4.844577e-01
# 85281    4.845820e-01
# 85283    4.845820e-01
# 85287    4.845820e-01
# 85290    4.846165e-01
# Name: Qvalue, Length: 3047, dtype: float64

# %%
filtered_qvalue=filtered_df4[filtered_df4["Qvalue"] < 0.05]
num_qvalue=len(filtered_qvalue)
print(f"number of qvalues <0.05: {num_qvalue}")
# Out:
# number of qvalues <0.05: 248

# %% [raw]
# # differentially expressed genes in ( Y_NR/Y_AL ) are =248

# %%
pwd
# Out:
# 'C:\\Users\\91918\\rna seq'

# %%
import os 
os.chdir("C:/Users//91918")

# %%
pwd
# Out:
# 'C:\\Users\\91918'

# %%
import pandas as pd
df5=pd.read_excel("liver proteome.xlsx")

# %%
df5
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 0                  O_AL / Y_NRDR  Q8C196        Q8C196       -0.809178
# 1                  O_NR / Y_NRDR  Q8C196        Q8C196       -0.913840
# 2                    O_NR / Y_DR  Q8C196        Q8C196       -0.710514
# 3                    O_AL / Y_DR  Q8C196        Q8C196       -0.605852
# 4                  O_NRDR / O_NR  Q8C196        Q8C196        0.615371
# ...                          ...     ...           ...             ...
# 85293                O_NR / Y_DR  Q9D710        Q9D710        0.136878
# 85294                O_AL / Y_AL  Q9QUR7        Q9QUR7        0.070849
# 85295              O_NRDR / O_NR  P54731        P54731       -0.067533
# 85296              Y_NRDR / Y_DR  Q99K48        Q99K48       -0.041905
# 85297                O_DR / O_AL  Q9Z0N1        Q9Z0N1        0.032731
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
filtered_df5=df5[df5["Comparison (group1/group2)"] == "Y_NRDR / Y_AL"]
display(filtered_df5)
# Out:
#       Comparison (group1/group2)   Group ProteinGroups  AVG Log2 Ratio  \
# 8                  Y_NRDR / Y_AL  Q8C196        Q8C196        0.441013
# 99                 Y_NRDR / Y_AL  Q99LB7        Q99LB7        0.236349
# 113                Y_NRDR / Y_AL  O88833        O88833        1.593028
# 123                Y_NRDR / Y_AL  Q99K67        Q99K67        0.921387
# 157                Y_NRDR / Y_AL  P52825        P52825        0.587015
# ...                          ...     ...           ...             ...
# 85264              Y_NRDR / Y_AL  P10711        P10711       -0.085954
# 85272              Y_NRDR / Y_AL  Q62087        Q62087        0.009904
# 85276              Y_NRDR / Y_AL  Q8BG05        Q8BG05       -0.062646
# 85284              Y_NRDR / Y_AL  Q9ESD7        Q9ESD7        0.009113
# 85291              Y_NRDR / Y_AL  P27786        P27786        0.043313
#
#        Absolute AVG Log2 Ratio         Pvalue         Qvalue  # of Ratios  \
# ...

# %%
display(filtered_df5["Qvalue"])
# Out:
# 8        4.330464e-185
# 99        2.655346e-69
# 113       2.671667e-66
# 123       1.412518e-64
# 157       4.841726e-59
#              ...
# 85264     4.844474e-01
# 85272     4.845157e-01
# 85276     4.845316e-01
# 85284     4.845820e-01
# 85291     4.846165e-01
# Name: Qvalue, Length: 3040, dtype: float64

# %%
filtered_qvalue=filtered_df5[filtered_df5["Qvalue"] < 0.05]
num_qvalue=len(filtered_qvalue)
print(f"number of qvalues <0.05: {num_qvalue}")
# Out:
# number of qvalues <0.05: 1304
